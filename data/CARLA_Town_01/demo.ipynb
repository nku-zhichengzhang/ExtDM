# %%
import pandas as pd
df = pd.read_csv('/mnt/hdd/zzc/data/video_prediction/CARLA_Town_01/no-traffic/video_train.csv')

pd.set_option('display.max_rows',50)

for i in range(len(df)):
    df['path'][i] = df['path'][i].split('/')[-1]

df
# Out:
# /tmp/ipykernel_16967/2140063882.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['path'][i] = df['path'][i].split('/')[-1]
#      Unnamed: 0          path
# 0             0    video_0.pt
# 1             1    video_1.pt
# 2             2    video_2.pt
# 3             3    video_3.pt
# 4             4    video_4.pt
# ..          ...           ...
# 403         403  video_420.pt
# 404         404  video_421.pt
# 405         405  video_422.pt
# 406         406  video_423.pt
# 407         407  video_424.pt
#
# [408 rows x 2 columns]

# %%
import pandas as pd
df = pd.read_csv('/mnt/hdd/zzc/data/video_prediction/CARLA_Town_01/no-traffic/video_test.csv')

pd.set_option('display.max_rows',50)

for i in range(len(df)):
    df['path'][i] = df['path'][i].split('/')[-1]

df
# Out:
# /tmp/ipykernel_16967/3091779136.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['path'][i] = df['path'][i].split('/')[-1]
#     Unnamed: 0          path
# 0          408  video_425.pt
# 1          409  video_426.pt
# 2          410  video_427.pt
# 3          411  video_428.pt
# 4          412  video_429.pt
# ..         ...           ...
# 95         503  video_528.pt
# 96         504  video_529.pt
# 97         505  video_530.pt
# 98         506  video_531.pt
# 99         507  video_532.pt
#
# [100 rows x 2 columns]

# %%
# actions_0.npy
# coords_0.npy
# video_0.pt

# %%
import torch

video = torch.load('/mnt/hdd/zzc/data/video_prediction/CARLA_Town_01/no-traffic/video_0.pt')
print(torch.min(video), torch.max(video), video.shape)
# [0-255] [1000, 128, 128, 3]

import einops
import mediapy as media
media.show_video(video.numpy(), fps=20)
# Out:
# tensor(0, dtype=torch.uint8) tensor(255, dtype=torch.uint8) torch.Size([1000, 128, 128, 3])
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="128" height="128" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %%
import numpy as np

actions = np.load('/mnt/hdd/zzc/data/video_prediction/CARLA_Town_01/no-traffic/actions_1.npy')

print(np.min(actions), np.max(actions), actions.shape)
# -1.5735552285261643 159.9499969482422 (1000, 11)

actions[100]
# array([ 1.33071884e+02,  5.94759941e+01,  1.83124538e-03, -4.79936576e-04,
#         2.94598984e-02, -3.94147841e-05,  0.00000000e+00,  2.00000000e+01,
#         1.36390244e+02,  5.94943962e+01,  0.00000000e+00])
# Out:
# -0.0031648873756595815 292.17022705078125 (1000, 11)
# array([ 1.33071884e+02,  5.94759941e+01,  1.83124538e-03, -4.79936576e-04,
#         2.94598984e-02, -3.94147841e-05,  0.00000000e+00,  2.00000000e+01,
#         1.36390244e+02,  5.94943962e+01,  0.00000000e+00])

# %%
import numpy as np

coords = np.load('/mnt/hdd/zzc/data/video_prediction/CARLA_Town_01/no-traffic/coords_1.npy')

print(np.min(coords), np.max(coords), coords.shape)
# -1.5735552285261643 159.9499969482422 (1000, 11)

coords[100]
# array([ 1.33071884e+02,  5.94759941e+01,  1.83124538e-03, -4.79936576e-04,
#         2.94598984e-02, -3.94147841e-05,  0.00000000e+00,  2.00000000e+01,
#         1.36390244e+02,  5.94943962e+01,  0.00000000e+00])
# Out:
# -0.0031648873756595815 292.17022705078125 (1000, 11)
# array([ 1.33071884e+02,  5.94759941e+01,  1.83124538e-03, -4.79936576e-04,
#         2.94598984e-02, -3.94147841e-05,  0.00000000e+00,  2.00000000e+01,
#         1.36390244e+02,  5.94943962e+01,  0.00000000e+00])

# %%
(actions == coords).all()
# Out:
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]])
